# %%
import warnings
# warnings.filterwarnings("ignore",category=DeprecationWarning)
warnings.filterwarnings("ignore")
from utils import utils
from app import run_app, App
from core.gen_topics import gen_topics
import pandas as pd
import copy
settings = utils.get_settings_notebook('../settings.json')
utils.pretty_print(settings)
# Out:
# /opt/Anaconda/anaconda3/envs/ucsd1/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# =======
# {
#     "extract": {
#         "cast": {
#             "filepath_or_buffer": "files/archive/AllMoviesCastingRaw.csv",
#             "sep": ";"
#         },
#         "directors": {
#             "filepath_or_buffer": "files/archive/900_acclaimed_directors_awards.csv",
#             "sep": ";"
#         },
#         "movies": {
#             "filepath_or_buffer": "files/archive/AllMoviesDetailsCleaned.csv",
#             "sep": ";"
#         }
#     },
#     "load": {
#         "constraints": [
#             {
#                 "field": "name",
#                 "name": "Companies",
#                 "node_name": "Company"
#             },
#             {
#                 "field": "name",
#                 "name": "Genres",
#                 "node_name": "Genre"
#             },
#             {
#                 "field": "name",
#                 "name": "People",
#                 "node_name": "Person"
#             },
#             {
#                 "field": "movie_id",
#                 "name": "Movies",
#                 "node_name": "Movie"
#             }
#         ],
#         "data": {
#             "company": [
#                 {
#                     "cols": [
#                         "name"
#                     ],
#                     "node_name": "Company",
#                     "ref": "c"
#                 }
#             ],
#             "genres": [
#                 {
#                     "cols": [
#                         "name"
#                     ],
#                     "node_name": "Genre",
#                     "ref": "g"
#                 }
#             ],
#             "movies": [
#                 {
#                     "cols": [
#                         "movie_id",
#                         "imdb_id",
#                         "lang",
#                         "title",
#                         "overview"
#                     ],
#                     "node_name": "Movie",
#                     "ref": "m"
#                 },
#                 {
#                     "cols": [
#                         "name"
#                     ],
#                     "needs": "m",
#                     "node_name": "Person",
#                     "ref": "d",
#                     "relations": [
#                         {
#                             "begins": "d",
#                             "begins_dir": "-",
#                             "ends": "m",
#                             "ends_dir": "->",
#                             "name": "DIRECTED"
#                         }
#                     ],
#                     "unwind": "directors"
#                 },
#                 {
#                     "cols": [
#                         "name"
#                     ],
#                     "needs": "m",
#                     "node_name": "Company",
#                     "ref": "c",
#                     "relations": [
#                         {
#                             "begins": "c",
#                             "begins_dir": "-",
#                             "ends": "m",
#                             "ends_dir": "->",
#                             "name": "PRODUCED"
#                         }
#                     ],
#                     "unwind": "companies"
#                 },
#                 {
#                     "cols": [
#                         "name"
#                     ],
#                     "needs": "m",
#                     "node_name": "Genre",
#                     "ref": "g",
#                     "relations": [
#                         {
#                             "begins": "m",
#                             "begins_dir": "-",
#                             "ends": "g",
#                             "ends_dir": "->",
#                             "name": "HAS_GENRE"
#                         }
#                     ],
#                     "unwind": "genres"
#                 },
#                 {
#                     "cols": [
#                         "name"
#                     ],
#                     "needs": "m",
#                     "node_name": "Person",
#                     "ref": "a",
#                     "relations": [
#                         {
#                             "begins": "a",
#                             "begins_dir": "-",
#                             "ends": "m",
#                             "ends_dir": "->",
#                             "name": "ACTED_IN"
#                         }
#                     ],
#                     "unwind": "actors"
#                 }
#             ],
#             "people": [
#                 {
#                     "cols": [
#                         "name",
#                         "gender"
#                     ],
#                     "node_name": "Person",
#                     "ref": "p"
#                 }
#             ]
#         }
#     },
#     "neo4j": {
#         "cap_insert": 25000,
#         "clear_data": true,
#         "db": null,
#         "file_folder": "../import/",
#         "insertion_mode": "rows",
#         "password": "1234",
#         "uri": "bolt://localhost:7687",
#         "username": "neo4j"
#     },
#     "transform": {
#         "cast": {
#             "column_map": {
#                 "actor1_gender": "actor1_gender",
#                 "actor1_name": "actor1_name",
#                 "actor2_gender": "actor2_gender",
#                 "actor2_name": "actor2_name",
#                 "actor3_gender": "actor3_gender",
#                 "actor3_name": "actor3_name",
#                 "actor4_gender": "actor4_gender",
#                 "actor4_name": "actor4_name",
#                 "actor5_gender": "actor5_gender",
#                 "actor5_name": "actor5_name",
#                 "director_gender": "director_gender",
#                 "director_name": "director_name",
#                 "id": "movie_id"
#             }
#         },
#         "directors": {
#             "column_map": {
#                 "Academy Fellowship": "acad_fellow",
#                 "name": "name"
#             }
#         },
#         "movies": {
#             "column_map": {
#                 "genres": "genres",
#                 "id": "movie_id",
#                 "imdb_id": "imdb_id",
#                 "original_language": "lang",
#                 "original_title": "title",
#                 "overview": "overview",
#                 "production_companies": "company"
#             }
#         }
#     }
# }
# ======

# %%
data_df = run_app(settings, 'extract_transform')
# Out:
# ==== TRANSFORM directors ====
# ==== TRANSFORM movies ====
# ==== TRANSFORM cast ====

# %%
data_df['movies'].shape
# Out:
# (11842, 9)

# %%
(df_movie_topics, df_topic_words) = movie_topics.batch_process(data_df['movies'][data_df['movies']['lang'] == 'en'])
# Out:
# 2022-12-08 16:41:50 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# 2022-12-08 16:41:50,378 : INFO : Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json: 193kB [00:00, 4.55MB/s]
# 2022-12-08 16:41:51 INFO: Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2022-12-08 16:41:51,627 : INFO : Loading these models for language: en (English):
# ============================
# | Processor    | Package   |
# ----------------------------
# | tokenize     | combined  |
# | pos          | combined  |
# | lemma        | combined  |
# | depparse     | combined  |
# | sentiment    | sstplus   |
# | constituency | wsj       |
# | ner          | ontonotes |
# ============================
#
# 2022-12-08 16:41:51 INFO: Use device: gpu
# 2022-12-08 16:41:51,627 : INFO : Use device: gpu
# 2022-12-08 16:41:51 INFO: Loading: tokenize
# 2022-12-08 16:41:51,628 : INFO : Loading: tokenize
# 2022-12-08 16:41:52 INFO: Loading: pos
# 2022-12-08 16:41:52,930 : INFO : Loading: pos
# 2022-12-08 16:41:53 INFO: Loading: lemma
# 2022-12-08 16:41:53,137 : INFO : Loading: lemma
# 2022-12-08 16:41:53 INFO: Loading: depparse
# 2022-12-08 16:41:53,155 : INFO : Loading: depparse
# 2022-12-08 16:41:53 INFO: Loading: sentiment
# 2022-12-08 16:41:53,294 : INFO : Loading: sentiment
# 2022-12-08 16:41:53 INFO: Loading: constituency
# 2022-12-08 16:41:53,563 : INFO : Loading: constituency
# 2022-12-08 16:41:53 INFO: Loading: ner
# 2022-12-08 16:41:53,863 : INFO : Loading: ner
# 2022-12-08 16:41:54 INFO: Done loading processors!
# 2022-12-08 16:41:54,186 : INFO : Done loading processors!

# %%
display(df_topic_words)
display(df_movie_topics)
# Out:
#               0           1          2          3           4            5  \
# 0     "mission"     "exist"  "colonel"     "army"      "goal"    "illegal"
# 1        "film"       "set"  "suicide"     "life"       "get"       "vice"
# 2      "murder"      "hold"    "house"     "base"     "clint"    "convict"
# 3        "help"  "daydream"     "find"     "life"     "death"        "set"
# 4        "life"      "meet"     "turn"     "find"  "daughter"       "take"
# ..          ...         ...        ...        ...         ...          ...
# 5   "filmmaker"      "film"     "talk"      "art"    "effect"      "dream"
# 6       "expel"     "thief"   "school"      "run"     "often"       "home"
# 7        "book"       "car"   "little"      "buy"     "owner"  "character"
# 8         "set"      "plot"   "follow"  "science"  "american"      "alain"
# 9     "antoine"       "use"     "give"     "item"   "receipt"       "tell"
#
#                  6                 7             8           9
# 0      "dangerous"       "eliminate"   "guerrilla"     "enemy"
# 1         "action"             "put"         "old"      "year"
# 2           "star"  "coincidentally"    "evidence"  "thriller"
# 3            "man"            "meet"    "wrongful"   "instead"
# 4          "young"          "father"         "way"      "last"
# ..             ...               ...           ...         ...
# 5     "production"      "technology"      "screen"      "room"
# 6   "professional"           "gafin"     "student"      "find"
# 7       "ensemble"           "lyric"  "percussion"    "happen"
# 8        "madness"            "hine"       "conne"       "web"
# 9          "world"           "story"         "way"      "want"
#
# [2620 rows x 10 columns]
#       movie_id topic
# 2           12     4
# 3           13     6
# 4           14     4
# 5           15     9
# 6           16     6
# ...        ...   ...
# 11792   463684  2615
# 11793   463800  2618
# 11794   463850  2612
# 11795   463944  2612
# 11796   463970  2615
#
# [7860 rows x 2 columns]
